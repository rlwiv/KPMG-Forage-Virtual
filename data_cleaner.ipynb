# %%
# import libraries
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 KB 29.9 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# File to Load (Remember to Change These)
kpmg_data = pd.ExcelFile("/work/KPMG/KPMG_VI.xlsx")

# %%
# Read each sheet in excel separately
Transactions = pd.read_excel(kpmg_data, 'Transactions')
NewCustomerList = pd.read_excel(kpmg_data, 'NewCustomerList')
CustomerDemographic = pd.read_excel(kpmg_data, 'CustomerDemographic')
CustomerAddress = pd.read_excel(kpmg_data, 'CustomerAddress')

# %% [markdown]
# Explore transactions data

# %%
Transactions.head(5)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved   Trek Bicycles     Standard        medium        large  ...
# 2     Approved      OHM Cycles     Standard           low       medium  ...
# 3     Approved  Norco Bicycles     Standard        medium       medium  ...
# 4     Approved  Giant Bicycles     Standard        medium        large  ...
#
# ...

# %%
Transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
#Using only the required columns 
Transactions = Transactions.iloc[:, 0:13]
Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
#Using only the required columns 
Transactions = Transactions.iloc[:, 0:13]
Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
#Checking the shape of the data
Transactions.shape
# Out:
# (20000, 13)

# %%
#Checking for null values
Transactions.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %% [markdown]
# 7 Columns have values that are missing data.

# %%
#Checking for duplicate values
Transactions.duplicated().sum()
# Out:
# 0

# %%
#check for uniqueness of each column
Transactions.nunique()
# Out:
# transaction_id             20000
# product_id                   101
# customer_id                 3494
# transaction_date             364
# online_order                   2
# order_status                   2
# brand                          6
# product_line                   4
# product_class                  3
# product_size                   3
# list_price                   296
# standard_cost                103
# product_first_sold_date      100
# dtype: int64

# %% [markdown]
# Review Transactions columns

# %%
Transactions.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
Transactions['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
Transactions['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
Transactions['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
Transactions['product_class'].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
Transactions['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %%
Transactions['product_first_sold_date']
# Out:
# 0        41245.0
# 1        41701.0
# 2        36361.0
# 3        36145.0
# 4        42226.0
#           ...
# 19995    37823.0
# 19996    35560.0
# 19997    40410.0
# 19998    38216.0
# 19999    36334.0
# Name: product_first_sold_date, Length: 20000, dtype: float64

# %%
#convert date column from integer to datetime
Transactions['product_first_sold_date'] = pd.to_datetime(Transactions['product_first_sold_date'], unit='s')
Transactions['product_first_sold_date'].head()
# Out:
# 0   1970-01-01 11:27:25
# 1   1970-01-01 11:35:01
# 2   1970-01-01 10:06:01
# 3   1970-01-01 10:02:25
# 4   1970-01-01 11:43:46
# Name: product_first_sold_date, dtype: datetime64[ns]

# %%
Transactions['product_first_sold_date'].head(10)
# Out:
# 0   1970-01-01 11:27:25
# 1   1970-01-01 11:35:01
# 2   1970-01-01 10:06:01
# 3   1970-01-01 10:02:25
# 4   1970-01-01 11:43:46
# 5   1970-01-01 10:50:31
# 6   1970-01-01 09:29:25
# 7   1970-01-01 11:05:15
# 8   1970-01-01 09:17:35
# 9   1970-01-01 10:36:56
# Name: product_first_sold_date, dtype: datetime64[ns]

# %% [markdown]
# Explore new customer data

# %%
NewCustomerList.head(5)
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
NewCustomerList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
#Dropping the unnamed columns
NewCustomerList.drop(['Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
       'Unnamed: 19', 'Unnamed: 20'], axis=1, inplace=True)

# %%
#Check the shape of the dataset
NewCustomerList.shape
# Out:
# (1000, 18)

# %%
#Checking for null values
NewCustomerList.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %% [markdown]
# 4 Columns have values that are missing data.

# %%
#Checking for duplicate values
NewCustomerList.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values

# %%
#Checking for uniquess of each column
NewCustomerList.nunique()
# Out:
# first_name                              940
# last_name                               961
# gender                                    3
# past_3_years_bike_related_purchases     100
# DOB                                     958
# job_title                               184
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        1
# owns_car                                  2
# tenure                                   23
# address                                1000
# postcode                                522
# state                                     3
# country                                   1
# property_valuation                       12
# Rank                                    324
# Value                                   324
# dtype: int64

# %% [markdown]
# Exploring the columns

# %%
NewCustomerList.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Rank', 'Value'],
#       dtype='object')

# %%
NewCustomerList['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
NewCustomerList[NewCustomerList.gender == "U"]
# Out:
#     first_name    last_name gender  past_3_years_bike_related_purchases DOB  \
# 59       Normy     Goodinge      U                                    5 NaT
# 226      Hatti     Carletti      U                                   35 NaT
# 324   Rozamond       Turtle      U                                   69 NaT
# 358      Tamas      Swatman      U                                   65 NaT
# 360      Tracy   Andrejevic      U                                   71 NaT
# 374     Agneta      McAmish      U                                   66 NaT
# 434      Gregg      Aimeric      U                                   52 NaT
# 439      Johna       Bunker      U                                   93 NaT
# 574    Harlene         Nono      U                                   69 NaT
# 598   Gerianne       Kaysor      U                                   15 NaT
# 664     Chicky      Sinclar      U                                   43 NaT
# ...

# %%
NewCustomerList['DOB'].value_counts()
# Out:
# 1993-11-02    2
# 1994-04-15    2
# 1963-08-25    2
# 1995-08-13    2
# 1987-01-15    2
#              ..
# 1958-05-14    1
# 1977-12-08    1
# 1993-12-19    1
# 1954-10-06    1
# 1995-10-19    1
# Name: DOB, Length: 958, dtype: int64

# %%
NewCustomerList['job_industry_category'].value_counts()
# Out:
# Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %%
NewCustomerList['wealth_segment'].value_counts()
# Out:
# Mass Customer        508
# High Net Worth       251
# Affluent Customer    241
# Name: wealth_segment, dtype: int64

# %%
NewCustomerList['state'].value_counts()
# Out:
# NSW    506
# VIC    266
# QLD    228
# Name: state, dtype: int64

# %%
NewCustomerList['owns_car'].value_counts()
# Out:
# No     507
# Yes    493
# Name: owns_car, dtype: int64

# %%
NewCustomerList['deceased_indicator'].value_counts()
# Out:
# N    1000
# Name: deceased_indicator, dtype: int64

# %% [markdown]
# Exploring Customer Demographic Data Set

# %%
CustomerDemographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
CustomerDemographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
CustomerDemographic.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %% [markdown]
# 6 Columns have values that are missing data.

# %%
#Checking for duplicate data
CustomerDemographic.duplicated().sum()
# Out:
# 0

# %%
#Checking for uniqueness of each column
CustomerDemographic.nunique()
# Out:
# customer_id                            4000
# first_name                             3139
# last_name                              3725
# gender                                    6
# past_3_years_bike_related_purchases     100
# DOB                                    3448
# job_title                               195
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        2
# default                                  90
# owns_car                                  2
# tenure                                   22
# dtype: int64

# %% [markdown]
# Exploring the columns

# %%
CustomerDemographic.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
CustomerDemographic['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# Femal        1
# F            1
# M            1
# Name: gender, dtype: int64

# %% [markdown]
# Certain categories are not correctly titled (M, F, Female).

# %%
# Replace inaccurate category titles
CustomerDemographic['gender'] = CustomerDemographic['gender'].replace('F','Female').replace('M','Male').replace('Femal','Female').replace

# %%
CustomerDemographic['gender'].value_counts()
# Out:
# <bound method Series.replace of 0       Female\n1         Male\n2         Male\n3         Male\n4       Female\n         ...  \n3995    Female\n3996    Female\n3997         U\n3998      Male\n3999      Male\nName: gender, Length: 4000, dtype: object>    4000
# Name: gender, dtype: int64

# %%
CustomerDemographic['past_3_years_bike_related_purchases'].value_counts()
# Out:
# 19    56
# 16    56
# 67    54
# 20    54
# 2     50
#       ..
# 8     28
# 85    27
# 86    27
# 95    27
# 92    24
# Name: past_3_years_bike_related_purchases, Length: 100, dtype: int64

# %%
CustomerDemographic['DOB'].value_counts()
# Out:
# 1978-01-30    7
# 1978-08-19    4
# 1964-07-08    4
# 1976-09-25    4
# 1976-07-16    4
#              ..
# 2001-01-22    1
# 1955-03-06    1
# 1966-08-05    1
# 1968-11-16    1
# 1958-08-02    1
# Name: DOB, Length: 3448, dtype: int64

# %%
CustomerDemographic['job_title'].value_counts()
# Out:
# Business Systems Development Analyst    45
# Social Worker                           44
# Tax Accountant                          44
# Internal Auditor                        42
# Legal Assistant                         41
#                                         ..
# Database Administrator II                4
# Health Coach I                           3
# Health Coach III                         3
# Research Assistant III                   3
# Developer I                              1
# Name: job_title, Length: 195, dtype: int64

# %%
CustomerDemographic['job_industry_category'].value_counts()
# Out:
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: job_industry_category, dtype: int64

# %%
CustomerDemographic['wealth_segment'].value_counts()
# Out:
# Mass Customer        2000
# High Net Worth       1021
# Affluent Customer     979
# Name: wealth_segment, dtype: int64

# %%
CustomerDemographic['deceased_indicator'].value_counts()
# Out:
# N    3998
# Y       2
# Name: deceased_indicator, dtype: int64

# %%
CustomerDemographic['default'].value_counts()
# Out:
# 100                                       113
# 1                                         112
# -1                                        111
# -100                                       99
# â°â´âµâââ                                  53
#                                          ...
# ç¤¾æç§å­¸é¢èªå­¸ç ç©¶æ                     31
# /dev/null; touch /tmp/blns.fail ; echo     30
# âªâªtestâª                                 29
# ì¸ëë°í ë¥´                                 27
# ,ãã»:*:ã»ãâ( â» Ï â» )ãã»:*:ã»ãâ           25
# Name: default, Length: 90, dtype: int64

# %% [markdown]
# Due to inconsistencies in 'default' column, the column should be dropped.

# %%
CustomerDemographic = CustomerDemographic.drop('default', axis=1)

# %%
# Updated Column Headers
CustomerDemographic.head(5)
# Out:
#    customer_id      first_name  last_name  \
# 0            1         Laraine  Medendorp
# 1            2             Eli    Bockman
# 2            3           Arlin     Dearle
# 3            4          Talbot        NaN
# 4            5  Sheila-kathryn     Calton
#
#                                               gender  \
# 0  <bound method Series.replace of 0       Female...
# 1  <bound method Series.replace of 0       Female...
# 2  <bound method Series.replace of 0       Female...
# 3  <bound method Series.replace of 0       Female...
# 4  <bound method Series.replace of 0       Female...
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# ...

# %%
CustomerDemographic['owns_car'].value_counts()
# Out:
# Yes    2024
# No     1976
# Name: owns_car, dtype: int64

# %%
CustomerDemographic['tenure'].value_counts()
# Out:
# 7.0     235
# 5.0     228
# 11.0    221
# 10.0    218
# 16.0    215
# 8.0     211
# 18.0    208
# 12.0    202
# 14.0    200
# 9.0     200
# 6.0     192
# 4.0     191
# 13.0    191
# 17.0    182
# 15.0    179
# 1.0     166
# 3.0     160
# 19.0    159
# 2.0     150
# 20.0     96
# 22.0     55
# 21.0     54
# Name: tenure, dtype: int64

# %% [markdown]
# Explore customer address data set

# %%
# View customer address headers
CustomerAddress.head(5)
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
CustomerAddress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
#Check for null values.
CustomerAddress.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
#Check for duplicate values
CustomerAddress.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no null or duplicate values

# %%
#Checking for uniqueness of each column
CustomerAddress.nunique()
# Out:
# customer_id           3999
# address               3996
# postcode               873
# state                    5
# country                  1
# property_valuation      12
# dtype: int64

# %% [markdown]
# Explore the columns

# %%
CustomerAddress['postcode'].value_counts()
# Out:
# 2170    31
# 2145    30
# 2155    30
# 2153    29
# 3977    26
#         ..
# 3331     1
# 3036     1
# 3321     1
# 3305     1
# 2143     1
# Name: postcode, Length: 873, dtype: int64

# %%
CustomerAddress['state'].value_counts()
# Out:
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64

# %%
CustomerAddress['country'].value_counts()
# Out:
# Australia    3999
# Name: country, dtype: int64

# %%
CustomerAddress['property_valuation'].value_counts()
# Out:
# 9     647
# 8     646
# 10    577
# 7     493
# 11    281
# 6     238
# 5     225
# 4     214
# 12    195
# 3     186
# 1     154
# 2     143
# Name: property_valuation, dtype: int64

# %%
#print to csv file after the cleaning

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=14b8853c-80ed-4a54-b307-d3d02cbb95bd' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
